# %% [markdown]
# ## waste management using CNN model

# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/39.5 MB 2.3 MB/s eta 0:00:17
#    - -------------------------------------- 1.6/39.5 MB 3.8 MB/s eta 0:00:11
#    -- ------------------------------------- 2.1/39.5 MB 3.0 MB/s eta 0:00:13
#    -- ------------------------------------- 2.6/39.5 MB 3.1 MB/s eta 0:00:13
#    --- ------------------------------------ 3.1/39.5 MB 3.1 MB/s eta 0:00:12
#    --- ------------------------------------ 3.9/39.5 MB 2.9 MB/s eta 0:00:13
#    ---- ----------------------------------- 4.5/39.5 MB 2.9 MB/s eta 0:00:12
#    ----- ---------------------------------- 5.2/39.5 MB 3.0 MB/s eta 0:00:12
#    ------ --------------------------------- 6.0/39.5 MB 3.1 MB/s eta 0:00:11
# ...

# %%
# pip install tensorflow
# pip install pandas
# pip instsall matplotlib as plt

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Importing necessary libraries
#       2 import numpy as np
# ----> 3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#       5 import cv2
#
# ModuleNotFoundError: No module named 'pandas'

# %%
train_path="DATASET/TRAIN"
test_path="DATASET/TEST"

# %%
# Importing Libraries
from tensorflow.keras.models import sequential 
from tensorflow.keras.layers import conv2D ,Maxpooling2D,Activation,Dropout,Flatten,Dense,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator,imh_to_array,load_img
from tensorflow.keras.utils import plot_model
from glob import golb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Importing Libraries
# ----> 2 from tensorflow.keras.models import sequential
#       3 from tensorflow.keras.layers import conv2D ,Maxpooling2D,Activation,Dropout,Flatten,Dense,BatchNormalization
#       4 from tensorflow.keras.preprocessing.image import ImageDataGenerator,imh_to_array,load_img
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# visualization
x_data = []
y_data = []
for category in golb(train_path+"/*"):
    for file in tqdm(golb(category+"/*")):
        img_array = cv2.imread(file)
        img_array =cv2color(img_array, COLOR_BGR2RGB)
        x_data.append(img_array)
        y_data.append(category.spilt("/")[-1])
        data = pd.DataFrame({"image":x_data,"lable":y_data})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       2 x_data = []
#       3 y_data = []
# ----> 4 for category in golb(train_path+"/*"):
#       5     for file in tqdm(golb(category+"/*")):
#       6         img_array = cv2.imread(file)
#
# NameError: name 'golb' is not defined
